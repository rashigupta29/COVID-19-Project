# %%
import pandas as pd

# %%
#df=pd.read_html('https://tinyurl.com/wnqrr8f',header=1)

# %%
#df[0].to_csv("Covid19.csv")

# %%
df=pd.read_csv("Covid19.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '1', 'Patient Number', 'State Patient Number',
#        'Date Announced', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],
#       dtype='object')

# %%
df
# Out:
#        Unnamed: 0        1  Patient Number State Patient Number  \
# 0               0      NaN             NaN                  NaN
# 1               1      2.0             1.0             KL-TS-P1
# 2               2      3.0             2.0             KL-AL-P1
# 3               3      4.0             3.0             KL-KS-P1
# 4               4      5.0             4.0                DL-P1
# ...           ...      ...             ...                  ...
# 13056       13056  13057.0             NaN                  NaN
# 13057       13057  13058.0             NaN                  NaN
# 13058       13058  13059.0             NaN                  NaN
# 13059       13059  13060.0             NaN                  NaN
# 13060       13060  13061.0             NaN                  NaN
#
#       Date Announced Age Bracket Gender             Detected City  \
# 0                NaN         NaN    NaN                       NaN
# 1         30/01/2020          20      F                  Thrissur
# 2         02/02/2020         NaN    NaN                 Alappuzha
# 3         03/02/2020         NaN    NaN                 Kasaragod
# 4         02/03/2020          45      M  East Delhi (Mayur Vihar)
# ...              ...         ...    ...                       ...
# 13056            NaN         NaN    NaN                       NaN
# 13057            NaN         NaN    NaN                       NaN
# 13058            NaN         NaN    NaN                       NaN
# 13059            NaN         NaN    NaN                       NaN
# 13060            NaN         NaN    NaN                       NaN
#
#       Detected District Detected State  ...  \
# 0                   NaN            NaN  ...
# 1              Thrissur         Kerala  ...
# 2             Alappuzha         Kerala  ...
# 3             Kasaragod         Kerala  ...
# 4            East Delhi          Delhi  ...
# ...                 ...            ...  ...
# 13056               NaN            NaN  ...
# 13057               NaN            NaN  ...
# 13058               NaN            NaN  ...
# 13059               NaN            NaN  ...
# 13060               NaN            NaN  ...
#
#                                                 Source_2  \
# 0                                                    NaN
# 1      https://weather.com/en-IN/india/news/news/2020...
# 2      https://weather.com/en-IN/india/news/news/2020...
# 3      https://twitter.com/ANI/status/122422148580539...
# 4      https://economictimes.indiatimes.com/news/poli...
# ...                                                  ...
# 13056                                                NaN
# 13057                                                NaN
# 13058                                                NaN
# 13059                                                NaN
# 13060                                                NaN
#
#                                                 Source_3  \
# 0                                                    NaN
# 1      https://weather.com/en-IN/india/news/news/2020...
# 2                                                    NaN
# 3      https://weather.com/en-IN/india/news/news/2020...
# 4                                                    NaN
# ...                                                  ...
# 13056                                                NaN
# 13057                                                NaN
# 13058                                                NaN
# 13059                                                NaN
# 13060                                                NaN
#
#                               Backup Notes Unnamed: 20 Unnamed: 21  \
# 0                                      NaN         NaN         NaN
# 1                       Student from Wuhan         NaN         NaN
# 2                       Student from Wuhan         NaN         NaN
# 3                       Student from Wuhan         NaN         NaN
# 4      Travel history to Italy and Austria         NaN         NaN
# ...                                    ...         ...         ...
# 13056                                  NaN         NaN         NaN
# 13057                                  NaN         NaN         NaN
# 13058                                  NaN         NaN         NaN
# 13059                                  NaN         NaN         NaN
# 13060                                  NaN         NaN         NaN
#
#       Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0             NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 13056         NaN         NaN         NaN         NaN         NaN
# 13057         NaN         NaN         NaN         NaN         NaN
# 13058         NaN         NaN         NaN         NaN         NaN
# 13059         NaN         NaN         NaN         NaN         NaN
# 13060         NaN         NaN         NaN         NaN         NaN
#
# [13061 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df[["Patient Number","Gender"]]
# Out:
#        Patient Number Gender
# 0                 NaN    NaN
# 1                 1.0      F
# 2                 2.0    NaN
# 3                 3.0    NaN
# 4                 4.0      M
# ...               ...    ...
# 13056             NaN    NaN
# 13057             NaN    NaN
# 13058             NaN    NaN
# 13059             NaN    NaN
# 13060             NaN    NaN
#
# [13061 rows x 2 columns]

# %% [markdown]
# # Here We can find that Male or Female which one is more affected by COVID-19 using Boxplot,Pie Chart and Bar.

# %% [markdown]
# 1. First we categorize Gender into parts then we can see that the female patient of Covid-19 is more than the male patient.

# %%
df.boxplot(column='Patient Number',by='Gender')

# %% [markdown]
# # 2. Here also we check more patient using bar chart.

# %%
height=['Male','Female']
left=[1,2]
tick_label=['Male','Female']
plt.bar(height,left,tick_label=tick_label,width=0.8)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# 3. Here we use pie chart to categorize the patient who are more affected by COVID-19 in Gender.
# and I use legend here to show which colour follow which column name.

# %%
labels = 'Patient Number','Male','Female'
colors = ['gold',  'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0)# explode 1st slice
sizes=[200,250,300]
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.legend('PMF')
plt.axis('equal')
plt.show()
